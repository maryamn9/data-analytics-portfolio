# %%
#Day 08 | 13 May 2026 | Maryam Naveen
#Topic: Pandas basics — data loading & inspection

import pandas as pd
import numpy as np

#loading the UK Accidents dataset
df = pd.read_csv(r'C:\Users\marya\OneDrive\Documents\GitHub\data-analytics-portfolio\day-07-sql-project\UK_Accident.csv')

print("Dataset loaded!")
print(f"Shape: {df.shape}")
# Out:
# Dataset loaded!
# Shape: (1504150, 33)

# %%
#First look at the data, it will show first 5 records in the dataset
df.head()
# Out:
#    Unnamed: 0 Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0           0  200501BS00001               525680.0                178240.0
# 1           1  200501BS00002               524170.0                181650.0
# 2           2  200501BS00003               524520.0                182240.0
# 3           3  200501BS00004               526900.0                177530.0
# 4           4  200501BS00005               528060.0                179040.0
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -0.191170  51.489096             1                  2                   1
# 1  -0.211708  51.520075             1                  3                   1
# 2  -0.206458  51.525301             1                  3                   2
# 3  -0.173862  51.482442             1                  3                   1
# 4  -0.156618  51.495752             1                  3                   1
#
# ...

# %%
#It will show column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504150 entries, 0 to 1504149
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Unnamed: 0                                   1504150 non-null  int64
#  1   Accident_Index                               1504150 non-null  object
#  2   Location_Easting_OSGR                        1504049 non-null  float64
#  3   Location_Northing_OSGR                       1504150 non-null  float64
#  4   Longitude                                    1504049 non-null  float64
#  5   Latitude                                     1504150 non-null  float64
#  6   Police_Force                                 1504150 non-null  int64
#  7   Accident_Severity                            1504150 non-null  int64
#  8   Number_of_Vehicles                           1504150 non-null  int64
# ...

# %%
#It will show basic statistics of the dataset
df.describe()
# Out:
#          Unnamed: 0  Location_Easting_OSGR  Location_Northing_OSGR  \
# count  1.504150e+06           1.504049e+06            1.504150e+06
# mean   2.530433e+05           4.396214e+05            3.001382e+05
# std    1.489162e+05           9.511616e+04            1.610218e+05
# min    0.000000e+00           6.495000e+04            0.000000e+00
# 25%    1.253452e+05           3.750600e+05            1.782600e+05
# 50%    2.506910e+05           4.399600e+05            2.688000e+05
# 75%    3.760370e+05           5.230600e+05            3.981500e+05
# max    5.700100e+05           6.553700e+05            1.208800e+06
#
#           Longitude      Latitude  Police_Force  Accident_Severity  \
# count  1.504049e+06  1.504150e+06  1.504150e+06       1.504150e+06
# mean  -1.436625e+00  5.258587e+01  3.020536e+01       2.838190e+00
# std    1.398078e+00  1.512524e+00  2.551603e+01       4.018423e-01
# min   -7.516225e+00  0.000000e+00  1.000000e+00       1.000000e+00
# ...

# %%
#It wil show missing values in each column, if any 
df.isnull().sum()
# Out:
# Unnamed: 0                                           0
# Accident_Index                                       0
# Location_Easting_OSGR                              101
# Location_Northing_OSGR                               0
# Longitude                                          101
# Latitude                                             0
# Police_Force                                         0
# Accident_Severity                                    0
# Number_of_Vehicles                                   0
# Number_of_Casualties                                 0
# Date                                                 0
# Day_of_Week                                          0
# Time                                               117
# Local_Authority_(District)                           0
# Local_Authority_(Highway)                            0
# 1st_Road_Class                                       0
# 1st_Road_Number                                      0
# ...

# %%
#Shape, columns, dtypes
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")
print(f"\nColumn names:\n{df.columns.tolist()}")
# Out:
# Rows: 1504150
# Columns: 33
#
# Column names:
# ['Unnamed: 0', 'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity', 'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week', 'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit', 'Junction_Control', '2nd_Road_Class', '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control', 'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions', 'Weather_Conditions', 'Road_Surface_Conditions', 'Special_Conditions_at_Site', 'Carriageway_Hazards', 'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident', 'LSOA_of_Accident_Location', 'Year']

# %%
#Checking value counts for key columns
print("Accident Severity:")
print(df['Accident_Severity'].value_counts())

print("\nDay of Week:")
print(df['Day_of_Week'].value_counts().sort_index())

print("\nUrban or Rural:")
print(df['Urban_or_Rural_Area'].value_counts())

print("\nYear:")
print(df['Year'].value_counts().sort_index())
# Out:
# Accident Severity:
# Accident_Severity
# 3    1280205
# 2     204504
# 1      19441
# Name: count, dtype: int64
#
# Day of Week:
# Day_of_Week
# 1    164972
# 2    213748
# 3    224110
# 4    226359
# 5    226411
# 6    247137
# 7    201413
# Name: count, dtype: int64
#
# Urban or Rural:
# Urban_or_Rural_Area
# 1    972007
# 2    532011
# 3       132
# Name: count, dtype: int64
#
# Year:
# Year
# 2005    198735
# 2006    189161
# 2007    182115
# 2009    163554
# 2010    154414
# 2011    151474
# 2012    179715
# 2013    138660
# 2014    146322
# Name: count, dtype: int64

# %%
#Summary of key findings
print("=" * 50)
print("DATASET SUMMARY")
print("=" * 50)
print(f"Total records: {len(df):,}")
print(f"Total columns: {df.shape[1]}")
print(f"Years covered: {df['Year'].min()} - {df['Year'].max()}")
print(f"Fatal accidents: {(df['Accident_Severity']==1).sum():,}")
print(f"Most dangerous day: Friday (Day 6) - {df[df['Day_of_Week']==6].shape[0]:,} accidents")
print(f"Urban accidents: {(df['Urban_or_Rural_Area']==1).sum():,}")
print(f"Missing values in Junction_Control: {df['Junction_Control'].isnull().sum():,}")
# Out:
# ...
# DATASET SUMMARY
# ...
# Total records: 1,504,150
# Total columns: 33
# Years covered: 2005 - 2014
# Fatal accidents: 19,441
# Most dangerous day: Friday (Day 6) - 247,137 accidents
# Urban accidents: 972,007
# Missing values in Junction_Control: 602,835
